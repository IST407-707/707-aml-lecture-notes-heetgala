# %% [markdown]
# ## Exercise 1

# %% [markdown]
# A useful way to understand gradient descent is to start with a known error function.  Imagine that we have a quadratic error function such as $f(x) = x^2$.  The gradient of this error function is just the first derivative of the function $f(x)$.  Using this, finish the following code to calculate the gradient.  After you've done that, try manipulating the learning rate.  What happens?  How many iterations are needed to reach the minimum?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and Derivative
f = lambda x: x ** 2
df = lambda x: 2 * x

# Gradient Descent
def gradient_descent(starting_x, learning_rate, n_iter=10):
    x_path = [starting_x] # x_path is an array that stores our successive "guesses".  
    for _ in range(n_iter):
        gradient = df(x_path[-1]) #We are applying the gradient function (dervative) evaluated at our last guess
        new_x = x_path[-1] - learning_rate * gradient
        x_path.append(new_x)
    return x_path

# Parameters
starting_x = 9
learning_rate = .1
n_iter = 15

# Run Gradient Descent
x_path = gradient_descent(starting_x, learning_rate, n_iter)

# Plotting
x = np.linspace(-10, 10, 100)
y = f(x)
plt.figure(figsize=(10, 5))
plt.plot(x, y, label='f(x) = x^2')

# Plot the steps with lines connecting them
for i in range(1, len(x_path)):
    plt.scatter(x_path[i-1:i+1], f(np.array(x_path[i-1:i+1])), color='red')
    plt.plot(x_path[i-1:i+1], f(np.array(x_path[i-1:i+1])), color='red')

plt.title('Gradient Descent Visualization with Paths')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# In the following, consider the the function $f(x) = (x-2)^4$.  Complete the code and examine the process of gradient decent.  What do you notice?  How are things different than in the previous example?

# %%
import numpy as np
import matplotlib.pyplot as plt

# Function and Derivative
f = lambda x: (x - 2) ** 4
df =  # What's the derivative?

# Gradient Descent
def gradient_descent(starting_x, learning_rate, n_iter=10):
    x_path = [starting_x]
    for _ in range(n_iter):
        gradient = df(x_path[-1])
        new_x = #what goes here?
        x_path.append(new_x)
        
    return x_path

# Parameters
starting_x = 3  
learning_rate = .1  
n_iter = 100

# Run Gradient Descent
x_path = gradient_descent(starting_x, learning_rate, n_iter)

# Plotting
x = np.linspace(1, 3, 1000)  # Range includes the minimum and starting point
y = f(x)
plt.figure(figsize=(10, 5))
plt.plot(x, y, label='f(x) = (x - 2)^4')

# Plot the steps with lines connecting them
for i in range(1, len(x_path)):
    plt.scatter(x_path[i-1:i+1], f(np.array(x_path[i-1:i+1])), color='red')
    plt.plot(x_path[i-1:i+1], f(np.array(x_path[i-1:i+1])), color='red')

plt.title('Gradient Descent Visualization')
plt.xlabel('x')
plt.ylabel('f(x)')
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# ## Exercise 2
#
# Take a few moments to play with the following code.  Try using the different activation functions (`identity`,`tanh`,`logistic`,`relu`) and solvers (`lbfgs`,`sgd`,`adam`).  Try reconfiguring the size and number of hidden layers.  Try changing the number of classes in your sample data. What do you find? Can you identify a good configuration for 10 classes?

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

# Generate a dataset
X, y = make_classification(n_samples=1000, n_features=20, n_informative=10, n_classes=4, random_state=1)

# Split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=1)

# Initialize the MLPClassifier
mlp = MLPClassifier(hidden_layer_sizes=(50,), max_iter=1000, alpha=1e-4,
                    solver='sgd', activation="logistic", verbose=10, random_state=1,
                    learning_rate_init=.1)

# Train the MLP
mlp.fit(X_train, y_train)

# Predictions
y_pred = mlp.predict(X_test)

# Evaluation
print(f"Accuracy: {accuracy_score(y_test, y_pred):.2f}")
# Out:
# Iteration 1, loss = 1.41382874
# Iteration 2, loss = 1.31912205
# Iteration 3, loss = 1.23575970
# Iteration 4, loss = 1.15366944
# Iteration 5, loss = 1.09093918
# Iteration 6, loss = 1.04342010
# Iteration 7, loss = 1.01232889
# Iteration 8, loss = 0.98977649
# Iteration 9, loss = 0.97478748
# Iteration 10, loss = 0.97178588
# Iteration 11, loss = 0.96143184
# Iteration 12, loss = 0.95640255
# Iteration 13, loss = 0.94859808
# Iteration 14, loss = 0.94494192
# Iteration 15, loss = 0.93921187
# Iteration 16, loss = 0.93261986
# Iteration 17, loss = 0.92823424
# Iteration 18, loss = 0.92322067
# Iteration 19, loss = 0.91500295
# Iteration 20, loss = 0.90941454
# Iteration 21, loss = 0.90283039
# Iteration 22, loss = 0.89398323
# Iteration 23, loss = 0.88590596
# Iteration 24, loss = 0.88074548
# Iteration 25, loss = 0.87126033
# Iteration 26, loss = 0.86412598
# Iteration 27, loss = 0.85483744
# Iteration 28, loss = 0.84547082
# Iteration 29, loss = 0.83799809
# Iteration 30, loss = 0.82705593
# Iteration 31, loss = 0.81873674
# Iteration 32, loss = 0.80757717
# Iteration 33, loss = 0.79763480
# Iteration 34, loss = 0.78768109
# Iteration 35, loss = 0.77839372
# Iteration 36, loss = 0.76767293
# Iteration 37, loss = 0.76060171
# Iteration 38, loss = 0.74901154
# Iteration 39, loss = 0.74173720
# Iteration 40, loss = 0.73423834
# Iteration 41, loss = 0.72286419
# Iteration 42, loss = 0.70967036
# Iteration 43, loss = 0.70147660
# Iteration 44, loss = 0.69255956
# Iteration 45, loss = 0.68218893
# Iteration 46, loss = 0.67345825
# Iteration 47, loss = 0.66379135
# Iteration 48, loss = 0.65397713
# Iteration 49, loss = 0.64231638
# Iteration 50, loss = 0.63259842
# Iteration 51, loss = 0.62595299
# Iteration 52, loss = 0.61678835
# Iteration 53, loss = 0.60743139
# Iteration 54, loss = 0.59730322
# Iteration 55, loss = 0.58746894
# Iteration 56, loss = 0.57886685
# Iteration 57, loss = 0.56998328
# Iteration 58, loss = 0.56162396
# Iteration 59, loss = 0.55591159
# Iteration 60, loss = 0.54787163
# Iteration 61, loss = 0.53697731
# Iteration 62, loss = 0.52942270
# Iteration 63, loss = 0.52117028
# Iteration 64, loss = 0.51344889
# Iteration 65, loss = 0.50339153
# Iteration 66, loss = 0.49825231
# Iteration 67, loss = 0.48959606
# Iteration 68, loss = 0.48064101
# Iteration 69, loss = 0.47460327
# Iteration 70, loss = 0.46632293
# Iteration 71, loss = 0.46051387
# Iteration 72, loss = 0.45223554
# Iteration 73, loss = 0.44416086
# Iteration 74, loss = 0.43837975
# Iteration 75, loss = 0.43132860
# Iteration 76, loss = 0.42509563
# Iteration 77, loss = 0.41721062
# Iteration 78, loss = 0.41152658
# Iteration 79, loss = 0.40439209
# Iteration 80, loss = 0.39829343
# Iteration 81, loss = 0.39130896
# Iteration 82, loss = 0.38695721
# Iteration 83, loss = 0.37912434
# Iteration 84, loss = 0.37450604
# Iteration 85, loss = 0.36834623
# Iteration 86, loss = 0.36277943
# Iteration 87, loss = 0.35927833
# Iteration 88, loss = 0.35174762
# Iteration 89, loss = 0.34563305
# Iteration 90, loss = 0.34001370
# Iteration 91, loss = 0.33738372
# Iteration 92, loss = 0.32956353
# Iteration 93, loss = 0.32451275
# Iteration 94, loss = 0.32029106
# Iteration 95, loss = 0.31382855
# Iteration 96, loss = 0.31032797
# Iteration 97, loss = 0.30400959
# Iteration 98, loss = 0.30090362
# Iteration 99, loss = 0.29529656
# Iteration 100, loss = 0.29138513
# Iteration 101, loss = 0.28632219
# Iteration 102, loss = 0.28254203
# Iteration 103, loss = 0.27813647
# Iteration 104, loss = 0.27483104
# Iteration 105, loss = 0.26893737
# Iteration 106, loss = 0.26603855
# Iteration 107, loss = 0.26182910
# Iteration 108, loss = 0.25797790
# Iteration 109, loss = 0.25371272
# Iteration 110, loss = 0.25021429
# Iteration 111, loss = 0.24625283
# Iteration 112, loss = 0.24398724
# Iteration 113, loss = 0.23938734
# Iteration 114, loss = 0.23545998
# Iteration 115, loss = 0.23321466
# Iteration 116, loss = 0.22889796
# Iteration 117, loss = 0.22623720
# Iteration 118, loss = 0.22271065
# Iteration 119, loss = 0.21983762
# Iteration 120, loss = 0.21583938
# Iteration 121, loss = 0.21292413
# Iteration 122, loss = 0.21014660
# Iteration 123, loss = 0.20736998
# Iteration 124, loss = 0.20352888
# Iteration 125, loss = 0.20100097
# Iteration 126, loss = 0.19808115
# Iteration 127, loss = 0.19530875
# Iteration 128, loss = 0.19312792
# Iteration 129, loss = 0.18980880
# Iteration 130, loss = 0.18682088
# Iteration 131, loss = 0.18450819
# Iteration 132, loss = 0.18214338
# Iteration 133, loss = 0.17921455
# Iteration 134, loss = 0.17692773
# Iteration 135, loss = 0.17401455
# Iteration 136, loss = 0.17169273
# Iteration 137, loss = 0.16943615
# Iteration 138, loss = 0.16656406
# Iteration 139, loss = 0.16439997
# Iteration 140, loss = 0.16230405
# Iteration 141, loss = 0.15939829
# Iteration 142, loss = 0.15800026
# Iteration 143, loss = 0.15562344
# Iteration 144, loss = 0.15314518
# Iteration 145, loss = 0.15132206
# Iteration 146, loss = 0.14962312
# Iteration 147, loss = 0.14735267
# Iteration 148, loss = 0.14512527
# Iteration 149, loss = 0.14345906
# Iteration 150, loss = 0.14136416
# Iteration 151, loss = 0.13934149
# Iteration 152, loss = 0.13722986
# Iteration 153, loss = 0.13554450
# Iteration 154, loss = 0.13441727
# Iteration 155, loss = 0.13209958
# Iteration 156, loss = 0.13067884
# Iteration 157, loss = 0.12869893
# Iteration 158, loss = 0.12738472
# Iteration 159, loss = 0.12546806
# Iteration 160, loss = 0.12416218
# Iteration 161, loss = 0.12233877
# Iteration 162, loss = 0.12074272
# Iteration 163, loss = 0.11950248
# Iteration 164, loss = 0.11762479
# Iteration 165, loss = 0.11635077
# Iteration 166, loss = 0.11460896
# Iteration 167, loss = 0.11351566
# Iteration 168, loss = 0.11190641
# Iteration 169, loss = 0.11068288
# Iteration 170, loss = 0.10919478
# Iteration 171, loss = 0.10788168
# Iteration 172, loss = 0.10686370
# Iteration 173, loss = 0.10516233
# Iteration 174, loss = 0.10405667
# Iteration 175, loss = 0.10284555
# Iteration 176, loss = 0.10179230
# Iteration 177, loss = 0.10057882
# Iteration 178, loss = 0.09937502
# Iteration 179, loss = 0.09828964
# Iteration 180, loss = 0.09708373
# Iteration 181, loss = 0.09591625
# Iteration 182, loss = 0.09470189
# Iteration 183, loss = 0.09375078
# Iteration 184, loss = 0.09265546
# Iteration 185, loss = 0.09158795
# Iteration 186, loss = 0.09116023
# Iteration 187, loss = 0.08986932
# Iteration 188, loss = 0.08869566
# Iteration 189, loss = 0.08761986
# Iteration 190, loss = 0.08665849
# Iteration 191, loss = 0.08601859
# Iteration 192, loss = 0.08504152
# Iteration 193, loss = 0.08410392
# Iteration 194, loss = 0.08304683
# Iteration 195, loss = 0.08231147
# Iteration 196, loss = 0.08130553
# Iteration 197, loss = 0.08061014
# Iteration 198, loss = 0.07963933
# Iteration 199, loss = 0.07885629
# Iteration 200, loss = 0.07783695
# Iteration 201, loss = 0.07707879
# Iteration 202, loss = 0.07643440
# Iteration 203, loss = 0.07546019
# Iteration 204, loss = 0.07481041
# Iteration 205, loss = 0.07416058
# Iteration 206, loss = 0.07331397
# Iteration 207, loss = 0.07263228
# Iteration 208, loss = 0.07187268
# Iteration 209, loss = 0.07122120
# Iteration 210, loss = 0.07067591
# Iteration 211, loss = 0.06999746
# Iteration 212, loss = 0.06934205
# Iteration 213, loss = 0.06857249
# Iteration 214, loss = 0.06811814
# Iteration 215, loss = 0.06739439
# Iteration 216, loss = 0.06701058
# Iteration 217, loss = 0.06601788
# Iteration 218, loss = 0.06554003
# Iteration 219, loss = 0.06488060
# Iteration 220, loss = 0.06437404
# Iteration 221, loss = 0.06367044
# Iteration 222, loss = 0.06315143
# Iteration 223, loss = 0.06254024
# Iteration 224, loss = 0.06200910
# Iteration 225, loss = 0.06147102
# Iteration 226, loss = 0.06097391
# Iteration 227, loss = 0.06034267
# Iteration 228, loss = 0.05989974
# Iteration 229, loss = 0.05928506
# Iteration 230, loss = 0.05875257
# Iteration 231, loss = 0.05849729
# Iteration 232, loss = 0.05785462
# Iteration 233, loss = 0.05738953
# Iteration 234, loss = 0.05684235
# Iteration 235, loss = 0.05637267
# Iteration 236, loss = 0.05597747
# Iteration 237, loss = 0.05539086
# Iteration 238, loss = 0.05499585
# Iteration 239, loss = 0.05461006
# Iteration 240, loss = 0.05405882
# Iteration 241, loss = 0.05370976
# Iteration 242, loss = 0.05321964
# Iteration 243, loss = 0.05283522
# Iteration 244, loss = 0.05240340
# Iteration 245, loss = 0.05203557
# Iteration 246, loss = 0.05162957
# Iteration 247, loss = 0.05113048
# Iteration 248, loss = 0.05075843
# Iteration 249, loss = 0.05036552
# Iteration 250, loss = 0.04999726
# Iteration 251, loss = 0.04964298
# Iteration 252, loss = 0.04920906
# Iteration 253, loss = 0.04883190
# Iteration 254, loss = 0.04853913
# Iteration 255, loss = 0.04812353
# Iteration 256, loss = 0.04774533
# Iteration 257, loss = 0.04730054
# Iteration 258, loss = 0.04701835
# Iteration 259, loss = 0.04665534
# Iteration 260, loss = 0.04625856
# Iteration 261, loss = 0.04600816
# Iteration 262, loss = 0.04564000
# Iteration 263, loss = 0.04525378
# Iteration 264, loss = 0.04496176
# Iteration 265, loss = 0.04463275
# Iteration 266, loss = 0.04444133
# Iteration 267, loss = 0.04404542
# Iteration 268, loss = 0.04377771
# Iteration 269, loss = 0.04343525
# Iteration 270, loss = 0.04308525
# Iteration 271, loss = 0.04285691
# Iteration 272, loss = 0.04250996
# Iteration 273, loss = 0.04223319
# Iteration 274, loss = 0.04197763
# Iteration 275, loss = 0.04167577
# Iteration 276, loss = 0.04141877
# Iteration 277, loss = 0.04107269
# Iteration 278, loss = 0.04090075
# Iteration 279, loss = 0.04054850
# Iteration 280, loss = 0.04026921
# Iteration 281, loss = 0.03998322
# Iteration 282, loss = 0.03971576
# Iteration 283, loss = 0.03946737
# Iteration 284, loss = 0.03920006
# Iteration 285, loss = 0.03894236
# Iteration 286, loss = 0.03871686
# Iteration 287, loss = 0.03845102
# Iteration 288, loss = 0.03820740
# Iteration 289, loss = 0.03800506
# Iteration 290, loss = 0.03776123
# Iteration 291, loss = 0.03746841
# Iteration 292, loss = 0.03726629
# Iteration 293, loss = 0.03710078
# Iteration 294, loss = 0.03682864
# Iteration 295, loss = 0.03657685
# Iteration 296, loss = 0.03637377
# Iteration 297, loss = 0.03613013
# Iteration 298, loss = 0.03590400
# Iteration 299, loss = 0.03568703
# Iteration 300, loss = 0.03551952
# Iteration 301, loss = 0.03528749
# Iteration 302, loss = 0.03506003
# Iteration 303, loss = 0.03483338
# Iteration 304, loss = 0.03468178
# Iteration 305, loss = 0.03441761
# Iteration 306, loss = 0.03427020
# Iteration 307, loss = 0.03402159
# Iteration 308, loss = 0.03382571
# Iteration 309, loss = 0.03363572
# Iteration 310, loss = 0.03346447
# Iteration 311, loss = 0.03321305
# Iteration 312, loss = 0.03305744
# Iteration 313, loss = 0.03289944
# Iteration 314, loss = 0.03267715
# Iteration 315, loss = 0.03247580
# Iteration 316, loss = 0.03230597
# Iteration 317, loss = 0.03214065
# Iteration 318, loss = 0.03193193
# Iteration 319, loss = 0.03181590
# Iteration 320, loss = 0.03160579
# Iteration 321, loss = 0.03139974
# Iteration 322, loss = 0.03124459
# Iteration 323, loss = 0.03112450
# Iteration 324, loss = 0.03091700
# Iteration 325, loss = 0.03080414
# Iteration 326, loss = 0.03059547
# Iteration 327, loss = 0.03042361
# Iteration 328, loss = 0.03022412
# Iteration 329, loss = 0.03007525
# Iteration 330, loss = 0.02993894
# Iteration 331, loss = 0.02980732
# Iteration 332, loss = 0.02962839
# Iteration 333, loss = 0.02947572
# Iteration 334, loss = 0.02933301
# Iteration 335, loss = 0.02915931
# Iteration 336, loss = 0.02900743
# Iteration 337, loss = 0.02886595
# Iteration 338, loss = 0.02867071
# Iteration 339, loss = 0.02855594
# Iteration 340, loss = 0.02842229
# Iteration 341, loss = 0.02825993
# Iteration 342, loss = 0.02810761
# Iteration 343, loss = 0.02798762
# Iteration 344, loss = 0.02781651
# Iteration 345, loss = 0.02771606
# Iteration 346, loss = 0.02755160
# Iteration 347, loss = 0.02740995
# Iteration 348, loss = 0.02729436
# Iteration 349, loss = 0.02712924
# Iteration 350, loss = 0.02700228
# Iteration 351, loss = 0.02692303
# Iteration 352, loss = 0.02675361
# Iteration 353, loss = 0.02665106
# Iteration 354, loss = 0.02649429
# Iteration 355, loss = 0.02637463
# Iteration 356, loss = 0.02623822
# Iteration 357, loss = 0.02614981
# Iteration 358, loss = 0.02601855
# Iteration 359, loss = 0.02588007
# Iteration 360, loss = 0.02573846
# Iteration 361, loss = 0.02564227
# Iteration 362, loss = 0.02550803
# Iteration 363, loss = 0.02540248
# Iteration 364, loss = 0.02525512
# Iteration 365, loss = 0.02515127
# Iteration 366, loss = 0.02502363
# Iteration 367, loss = 0.02494292
# Iteration 368, loss = 0.02481212
# Iteration 369, loss = 0.02471084
# Iteration 370, loss = 0.02459739
# Iteration 371, loss = 0.02450221
# Iteration 372, loss = 0.02437556
# Iteration 373, loss = 0.02427471
# Iteration 374, loss = 0.02417973
# Iteration 375, loss = 0.02403838
# Iteration 376, loss = 0.02394030
# Iteration 377, loss = 0.02382908
# Iteration 378, loss = 0.02372296
# Iteration 379, loss = 0.02360325
# Iteration 380, loss = 0.02353178
# Iteration 381, loss = 0.02343338
# Iteration 382, loss = 0.02330810
# Iteration 383, loss = 0.02320696
# Iteration 384, loss = 0.02312586
# Iteration 385, loss = 0.02300774
# Iteration 386, loss = 0.02292051
# Iteration 387, loss = 0.02282580
# Iteration 388, loss = 0.02273222
# Iteration 389, loss = 0.02261111
# Iteration 390, loss = 0.02251409
# Iteration 391, loss = 0.02243717
# Iteration 392, loss = 0.02233381
# Iteration 393, loss = 0.02225381
# Iteration 394, loss = 0.02213459
# Iteration 395, loss = 0.02206534
# Iteration 396, loss = 0.02197520
# Iteration 397, loss = 0.02189837
# Iteration 398, loss = 0.02177584
# Iteration 399, loss = 0.02169864
# Iteration 400, loss = 0.02161677
# Iteration 401, loss = 0.02150162
# Iteration 402, loss = 0.02145030
# Iteration 403, loss = 0.02137374
# Iteration 404, loss = 0.02126542
# Iteration 405, loss = 0.02118411
# Iteration 406, loss = 0.02108421
# Iteration 407, loss = 0.02100478
# Iteration 408, loss = 0.02091763
# Iteration 409, loss = 0.02085363
# Iteration 410, loss = 0.02075600
# Iteration 411, loss = 0.02067514
# Iteration 412, loss = 0.02059690
# Iteration 413, loss = 0.02051774
# Iteration 414, loss = 0.02042525
# Iteration 415, loss = 0.02036100
# Training loss did not improve more than tol=0.000100 for 10 consecutive epochs. Stopping.
# Accuracy: 0.74

# %% [markdown]
# ## Exercise 3
#
# Check out the [Tensorflow Playground](https://playground.tensorflow.org/#activation=tanh&batchSize=10&dataset=circle&regDataset=reg-plane&learningRate=0.03&regularizationRate=0&noise=0&networkShape=4,2&seed=0.80814&showTestData=false&discretize=false&percTrainData=50&x=true&y=true&xTimesY=false&xSquared=false&ySquared=false&cosX=false&sinX=false&cosY=false&sinY=false&collectStats=false&problem=classification&initZero=false&hideText=false). Explore the following:
#
#    - The patterns learned by a neural net. Try training the default neural network by clicking the Run button (top left). Notice how it quickly finds a good solution for the classification task. The neurons in the first hidden layer have learned simple patterns, while the neurons in the second hidden layer have learned to combine the simple patterns of the first hidden layer into more complex patterns. In general, the more layers there are, the more complex the patterns can be.
#
#    - Activation functions. Try replacing the tanh activation function with a ReLU activation function, and train the network again. Notice that it finds a solution even faster, but this time the boundaries are linear. This is due to the shape of the ReLU function.
#    - The risk of local minima. Modify the network architecture to have just one hidden layer with three neurons. Train it multiple times (to reset the network weights, click the Reset button next to the Play button). Notice that the training time varies a lot, and sometimes it even gets stuck in a local minimum.
#    - What happens when neural nets are too small? Remove one neuron to keep just two. Notice that the neural network is now incapable of finding a good solution, even if you try multiple times. The model has too few parameters and systematically underfits the training set.
#    - What happens when neural nets are large enough? Set the number of neurons to eight, and train the network several times. Notice that it is now consistently fast and never gets stuck. This highlights an important finding in neural network theory: large neural networks rarely get stuck in local minima, and even when they do these local optima are often almost as good as the global optimum. However, they can still get stuck on long plateaus for a long time.
#    - The risk of vanishing gradients in deep networks. Select the spiral dataset (the bottom-right dataset under “DATA”), and change the network architecture to have four hidden layers with eight neurons each. Notice that training takes much longer and often gets stuck on plateaus for long periods of time. Also notice that the neurons in the highest layers (on the right) tend to evolve faster than the neurons in the lowest layers (on the left). This problem, called the vanishing gradients problem, can be alleviated with better weight initialization and other techniques, better optimizers (such as AdaGrad or Adam), or batch normalization. (discussed in Chapter 11 in the book).

# %% [markdown]
# ## Exercise 3
#
# Try building a MLP in Keras to fit the MNIST handwriting data using the Sequential API. Here are some tips:
#
# - Make sure to flatten your images with a "Flatten" layer
# - Add one or two Dense layers with ReLU activation
# - Finish with a dense output layer with 10 neurons (one for each digit)
# - Compile the model with the `adam` optimizer, `sparse_categorical_crossentropy` loss, and `accuracy` metric
# - Use a validation_split parameter with 20 percent of your data for validation during training
# - Train with a reasonable number of epochs (e.g. 5-10) and evaluate your performance on the test set
# - Explore with different numbers of neurons, layers, and epochs!

# %%
#Just to get you started, here's some data!
from tensorflow.keras.datasets import mnist
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Tensorflows data is from 0-255, so here we just normalize to the 0-1 range:
x_train, x_test = x_train / 255.0, x_test / 255.0
